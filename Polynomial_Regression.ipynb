# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nighty13/Polynomial_Regression/blob/master/Polynomial_Regression.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(0)
points=500
X=np.linspace(-3,3,points)
y=np.sin(X)+np.random.uniform(-0.5,0.5,points)
plt.scatter(X,y)

# %%
model=Sequential()
model.add(Dense(50,activation='sigmoid',input_dim=1))
model.add(Dense(30,activation='sigmoid'))
model.add(Dense(1))

adam=Adam(lr=0.01)
#mean square error loss fnc
model.compile(loss='mse',optimizer=adam)
model.fit(X,y,epochs=60)
# Out:
# Epoch 1/60
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4791
# Epoch 2/60
# 500/500 [==============================] - 0s 54us/step - loss: 0.2498
# Epoch 3/60
# 500/500 [==============================] - 0s 51us/step - loss: 0.2436
# Epoch 4/60
# 500/500 [==============================] - 0s 53us/step - loss: 0.2434
# Epoch 5/60
# 500/500 [==============================] - 0s 50us/step - loss: 0.2251
# Epoch 6/60
# 500/500 [==============================] - 0s 58us/step - loss: 0.2173
# Epoch 7/60
# 500/500 [==============================] - 0s 52us/step - loss: 0.2297
# Epoch 8/60
# 500/500 [==============================] - 0s 53us/step - loss: 0.2053
# Epoch 9/60
# 500/500 [==============================] - 0s 52us/step - loss: 0.1928
# Epoch 10/60
# 500/500 [==============================] - 0s 50us/step - loss: 0.1841
# Epoch 11/60
# 500/500 [==============================] - 0s 53us/step - loss: 0.1766
# Epoch 12/60
# ...

# %%
predictions=model.predict(X)
plt.scatter(X,y)
plt.plot(X,predictions,'ro')
plt.scatter(X,y)
